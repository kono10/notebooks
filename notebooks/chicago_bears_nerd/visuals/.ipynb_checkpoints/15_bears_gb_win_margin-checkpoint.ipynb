# %%
import altair as alt
import pandas as pd
import numpy as np
import warnings 
import os
import glob

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_row', 500)

# %%
file_path = "../data/team_ranks/*.csv"

# %%
file_paths = glob.glob(os.path.join(file_path))

# %%
pds = list()

# %%
for file_path in file_paths:
    print(file_path)
    df = pd.read_csv(file_path).query("Rank <= 5")
    if df.Team.eq("Chicago").any():
        print("found data")
        pds.append(df)
# Out:
# ../data/team_ranks/_nfl_stat_punts_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_tackles_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_average_scoring_margin_20220913.csv
# ../data/team_ranks/_nfl_stat_yards_per_point_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_yards_per_point_margin_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_points_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_points_per_play_margin_20220913.csv
# ../data/team_ranks/_nfl_stat_touchdowns_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_red_zone_scoring_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_red_zone_scores_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_red_zone_scoring_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_extra_point_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_extra_points_made_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_two_point_conversion_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_two_point_conversions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_points_per_field_goal_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_extra_point_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_two_point_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_offensive_touchdowns_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_defensive_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_special_teams_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_offensive_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_defensive_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_special_teams_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_offensive_point_share_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_1st_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_2nd_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_3rd_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_4th_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_overtime_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_1st_half_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_2nd_half_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_1st_quarter_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_2nd_quarter_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_3rd_quarter_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_4th_quarter_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_1st_half_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_2nd_half_time_of_possession_share_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_plays_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_yards_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_third_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_third_down_conversions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_fourth_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_fourth_down_conversions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_average_time_of_possession_net_of_ot_20220913.csv
# ../data/team_ranks/_nfl_stat_time_of_possession_pct_net_of_ot_20220913.csv
# ../data/team_ranks/_nfl_stat_seconds_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_first_downs_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_third_down_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_fourth_down_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_punts_per_offensive_score_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_solo_tackles_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_assisted_tackles_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_rushing_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_rushing_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_rushing_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_rushing_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_yards_per_rush_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_rushing_play_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_rushing_touchdown_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_rushing_first_down_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_rushing_yards_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_pass_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_completions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_incompletions_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_completion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_gross_passing_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_yards_per_pass_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_yards_per_completion_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_passing_touchdowns_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_touchdown_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_qb_sacked_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_qb_sacked_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_first_down_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_average_team_passer_rating_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_play_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_passing_yards_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_other_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_field_goal_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_field_goals_made_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_field_goals_got_blocked_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_kicking_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_punt_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_punts_got_blocked_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_gross_punt_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_net_punt_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_kickoffs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_touchbacks_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_kickoff_touchback_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_field_goal_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_field_goal_got_blocked_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_field_goal_conversion_pct_net_of_blocks_20220913.csv
# ../data/team_ranks/_nfl_stat_punt_blocked_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_net_yards_per_punt_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_gross_yards_per_successful_punt_20220913.csv
# ../data/team_ranks/_nfl_stat_net_yards_per_successful_punt_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opp_yards_per_point_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_points_per_play_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_red_zone_scoring_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_red_zone_scores_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_red_zone_scoring_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_extra_point_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_extra_points_made_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_two_point_conversion_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_two_point_conversions_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_points_per_field_goal_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_extra_point_conversion_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_two_point_conversion_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_offensive_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_defensive_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_special_teams_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_offensive_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_defensive_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_special_teams_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_offensive_point_share_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opp_1st_quarter_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opp_2nd_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opp_3rd_quarter_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opp_4th_quarter_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opp_overtime_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_1st_half_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_2nd_half_points_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_plays_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_yards_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_third_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_third_down_conversions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_fourth_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_fourth_down_conversions_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_average_time_of_possession_net_of_ot_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_time_of_possession_pct_net_of_ot_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_seconds_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_first_downs_per_play_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_third_down_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_fourth_down_conversion_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_punts_per_play_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_punts_per_offensive_score_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_tackles_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_solo_tackles_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_assisted_tackles_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_touchdowns_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_yards_per_rush_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_play_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_touchdown_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_first_down_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_rushing_yards_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_pass_attempts_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_completions_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_incompletions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_completion_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_passing_yards_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_gross_passing_yards_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_yards_per_pass_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_yards_per_completion_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_passing_first_downs_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_passing_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_passing_touchdown_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_average_team_passer_rating_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_sack_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_passing_play_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_passing_yards_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_sacks_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_passing_first_down_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_other_touchdowns_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_field_goal_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_field_goals_made_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_field_goals_blocked_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_kicking_points_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_punt_attempts_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_punts_blocked_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_gross_punt_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_net_punt_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_kickoffs_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_touchbacks_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_kickoff_touchback_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_field_goal_conversion_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_block_field_goal_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_field_goal_conversion_pct_net_of_blocks_20220913.csv
# ../data/team_ranks/_nfl_stat_block_punt_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_net_yards_per_punt_attempt_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_gross_yards_per_successful_punt_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_net_yards_per_successful_punt_20220913.csv
# ../data/team_ranks/_nfl_stat_interceptions_thrown_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_percent_of_games_with_an_interception_thrown_20220913.csv
# ../data/team_ranks/_nfl_stat_fumbles_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_fumbles_lost_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_fumbles_not_lost_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_safeties_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_giveaways_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_turnover_margin_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_interceptions_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_percent_of_games_with_an_interception_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_fumbles_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_fumbles_lost_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_fumbles_not_lost_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_safeties_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_takeaways_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_pass_intercepted_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_fumble_recovery_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_giveaway_fumble_recovery_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_takeaway_fumble_recovery_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_interception_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_fumble_recovery_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_giveaway_fumble_recovery_pct_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_takeaway_fumble_recovery_pct_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_penalties_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_penalty_yards_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_penalty_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_penalties_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_penalty_yards_per_game_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_penalty_first_downs_per_game_20220913.csv
# ../data/team_ranks/_nfl_stat_penalty_yards_per_penalty_20220913.csv
# ../data/team_ranks/_nfl_stat_penalties_per_play_20220913.csv
# found data
# ../data/team_ranks/_nfl_stat_opponent_penalty_yards_per_penalty_20220913.csv
# ../data/team_ranks/_nfl_stat_opponent_penalties_per_play_20220913.csv
# found data

# %%
df_bears = pd.concat(pds)

# %%
df_bears_only = df_bears[df_bears.Team.eq("Chicago") & df_bears["2022"] > 0]

# %%
df = pd.read_csv("../data/team_ranks/_nfl_stat_incompletions_per_game_20220913.csv")

# %%
df
# Out:
#     Unnamed: 0  Rank           Team  2022  Last 3  Last 1  Home  Away  2021  \
# 0            0     1      NY Giants   4.0     4.0     4.0   0.0   4.0  14.2
# 1            1     2        Buffalo   5.0     5.0     5.0   0.0   5.0  13.4
# 2            2     2        Seattle   5.0     5.0     5.0   5.0   0.0  10.1
# 3            3     4    LA Chargers   8.0     8.0     8.0   8.0   0.0  13.6
# 4            4     5        Chicago   9.0     9.0     9.0   9.0   0.0  12.4
# 5            5     5      Tampa Bay   9.0     9.0     9.0   0.0   9.0  14.3
# 6            6     5    New England   9.0     9.0     9.0   0.0   9.0  10.3
# 7            7     5    Kansas City   9.0     9.0     9.0   0.0   9.0  13.0
# 8            8     5      Minnesota   9.0     9.0     9.0   9.0   0.0  12.1
# 9            9    10          Miami  10.0    10.0    10.0  10.0   0.0  12.4
# 10          10    11    New Orleans  11.0    11.0    11.0   0.0  11.0  12.4
# 11          11    11       Carolina  11.0    11.0    11.0  11.0   0.0  14.8
# 12          12    13        LA Rams  12.0    12.0    12.0  12.0   0.0  11.6
# 13          13    14        Atlanta  13.0    13.0    13.0  13.0   0.0  11.5
# 14          14    14      Tennessee  13.0    13.0    13.0  13.0   0.0  10.3
# 15          15    14         Denver  13.0    13.0    13.0   0.0  13.0  11.0
# 16          16    14      Green Bay  13.0    13.0    13.0   0.0  13.0  11.1
# 17          17    14      Baltimore  13.0    13.0    13.0   0.0  13.0  12.6
# 18          18    19     Washington  14.0    14.0    14.0  14.0   0.0  11.4
# 19          19    19        Houston  14.0    14.0    14.0  14.0   0.0  11.3
# 20          20    19        Arizona  14.0    14.0    14.0  14.0   0.0  10.6
# 21          21    19   Philadelphia  14.0    14.0    14.0   0.0  14.0  11.5
# 22          22    23      Las Vegas  15.0    15.0    15.0   0.0  15.0  12.4
# 23          23    23  San Francisco  15.0    15.0    15.0   0.0  15.0  10.1
# 24          24    25        Detroit  16.0    16.0    16.0  16.0   0.0  11.6
# 25          25    25      Cleveland  16.0    16.0    16.0   0.0  16.0  11.8
# 26          26    27     Pittsburgh  17.0    17.0    17.0   0.0  17.0  14.1
# 27          27    28   Jacksonville  18.0    18.0    18.0   0.0  18.0  14.3
# 28          28    28   Indianapolis  18.0    18.0    18.0   0.0  18.0  11.6
# 29          29    30     Cincinnati  20.0    20.0    20.0  20.0   0.0  10.3
# 30          30    31         Dallas  21.0    21.0    21.0  21.0   0.0  12.4
# 31          31    32        NY Jets  22.0    22.0    22.0  22.0   0.0  14.5
#
#           asof                               url
# 0   2022-09-13  /nfl/stat/incompletions-per-game
# 1   2022-09-13  /nfl/stat/incompletions-per-game
# 2   2022-09-13  /nfl/stat/incompletions-per-game
# 3   2022-09-13  /nfl/stat/incompletions-per-game
# 4   2022-09-13  /nfl/stat/incompletions-per-game
# 5   2022-09-13  /nfl/stat/incompletions-per-game
# 6   2022-09-13  /nfl/stat/incompletions-per-game
# 7   2022-09-13  /nfl/stat/incompletions-per-game
# 8   2022-09-13  /nfl/stat/incompletions-per-game
# 9   2022-09-13  /nfl/stat/incompletions-per-game
# 10  2022-09-13  /nfl/stat/incompletions-per-game
# 11  2022-09-13  /nfl/stat/incompletions-per-game
# 12  2022-09-13  /nfl/stat/incompletions-per-game
# 13  2022-09-13  /nfl/stat/incompletions-per-game
# 14  2022-09-13  /nfl/stat/incompletions-per-game
# 15  2022-09-13  /nfl/stat/incompletions-per-game
# 16  2022-09-13  /nfl/stat/incompletions-per-game
# 17  2022-09-13  /nfl/stat/incompletions-per-game
# 18  2022-09-13  /nfl/stat/incompletions-per-game
# 19  2022-09-13  /nfl/stat/incompletions-per-game
# 20  2022-09-13  /nfl/stat/incompletions-per-game
# 21  2022-09-13  /nfl/stat/incompletions-per-game
# 22  2022-09-13  /nfl/stat/incompletions-per-game
# 23  2022-09-13  /nfl/stat/incompletions-per-game
# 24  2022-09-13  /nfl/stat/incompletions-per-game
# 25  2022-09-13  /nfl/stat/incompletions-per-game
# 26  2022-09-13  /nfl/stat/incompletions-per-game
# 27  2022-09-13  /nfl/stat/incompletions-per-game
# 28  2022-09-13  /nfl/stat/incompletions-per-game
# 29  2022-09-13  /nfl/stat/incompletions-per-game
# 30  2022-09-13  /nfl/stat/incompletions-per-game
# 31  2022-09-13  /nfl/stat/incompletions-per-game

# %%
chart_title = "Stat"
x_cfgs = {"shorthand":"Rank", "title":"Rank"}
y_cfgs = {"shorthand":"Team", "title":"Team"}

# background etc.
primary_color = "#0B162A" 
# font etc.
secondary_color = "#c83803"
axisLeftKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, labelFontSize=15, titleFontSize=17)
axisBottomKwargs = dict(labelColor=secondary_color, titleColor=secondary_color,labelFontSize=15, titleFontSize=17)
legendKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, strokeColor='gray', fillColor=primary_color, padding=10, cornerRadius=10,orient='top-right', labelFontSize=15, titleFontSize=15)

# %%
chart = alt.Chart(df, width=1500, height=1500, title=chart_title)\
.mark_bar(color="white", opacity=1)\
.encode(
    x=alt.X(**x_cfgs,
    ),
    y=alt.Y(**y_cfgs,sort=alt.EncodingSortField(field="rank", order="descending")
    ),
    tooltip=[
        alt.Tooltip(shorthand="2022", title="Value"),
        alt.Tooltip(**x_cfgs),
        alt.Tooltip(**y_cfgs),
    ]
)



# put names inplace of bar
#chart.mark_text().encode(text="Team")\

chart\
.configure(background=primary_color)\
.configure_axis(gridColor="grey", gridDash=[6,4])\
.configure_axisLeft(**axisLeftKwargs)\
.configure_axisBottom(**axisBottomKwargs)\
.configure_title(color=secondary_color, fontSize=25)\
.configure_legend(**legendKwargs)
# Out:
# alt.Chart(...)

# %%
import altair as alt
import pandas as pd
import numpy as np
import warnings

# %%
df_summary = pd.read_csv("../data/spread_history/chi_spread_summary.csv")

# %%
df = pd.read_csv("../data/spread_history/2021_chi_games_spread.csv")

# %%
df
# Out:
#     Unnamed: 0  Week #  Day          Date Time (ET) Unnamed: 5  \
# 0            0       1  Sun  Sep 12, 2021      8:20          @
# 1            1       2  Sun  Sep 19, 2021      1:00        NaN
# 2            2       3  Sun  Sep 26, 2021      1:00          @
# 3            3       4  Sun   Oct 3, 2021      1:00        NaN
# 4            4       5  Sun  Oct 10, 2021      4:04          @
# 5            5       6  Sun  Oct 17, 2021      1:00        NaN
# 6            6       7  Sun  Oct 24, 2021      4:25          @
# 7            7       8  Sun  Oct 31, 2021      1:00        NaN
# 8            8       9  Mon   Nov 8, 2021      8:15          @
# 9            9      11  Sun  Nov 21, 2021      1:00        NaN
# 10          10      12  Thu  Nov 25, 2021     12:30          @
# 11          11      13  Sun   Dec 5, 2021      1:00        NaN
# 12          12      14  Sun  Dec 12, 2021      8:20          @
# 13          13      15  Mon  Dec 20, 2021      8:15        NaN
# 14          14      16  Sun  Dec 26, 2021      4:04          @
# 15          15      17  Sun   Jan 2, 2022      1:00        NaN
# 16          16      18  Sun   Jan 9, 2022      1:00          @
#
#                 Opponent    Score   Spread   Total  Notes
# 0       Los Angeles Rams  L 14-34     L +8  O 46.5    NaN
# 1     Cincinnati Bengals  W 20-17   W -1.5  U 44.5    NaN
# 2       Cleveland Browns   L 6-26   L +7.5  U 44.5    NaN
# 3          Detroit Lions  W 24-14     W -3  U 41.5    NaN
# 4      Las Vegas Raiders   W 20-9   W +5.5  U 45.5    NaN
# 5      Green Bay Packers  L 14-24     L +6    U 44    NaN
# 6   Tampa Bay Buccaneers   L 3-38  L +11.5    U 47    NaN
# 7    San Francisco 49ers  L 22-33     L +4  O 39.5    NaN
# 8    Pittsburgh Steelers  L 27-29   W +6.5  O 38.5    NaN
# 9       Baltimore Ravens  L 13-16     W +5  U 43.5    NaN
# 10         Detroit Lions  W 16-14     L -3    U 41    NaN
# 11     Arizona Cardinals  L 22-33   L +7.5    O 42    NaN
# 12     Green Bay Packers  L 30-45  L +11.5    O 43    NaN
# 13     Minnesota Vikings   L 9-17   L +6.5  U 44.5    NaN
# 14      Seattle Seahawks  W 25-24   W +6.5  O 41.5    NaN
# 15       New York Giants   W 29-3   W -6.5  U 36.5    NaN
# 16     Minnesota Vikings  L 17-31     L +4  O 44.5    NaN

# %%
df = df.rename({"Unnamed: 5":"away"}, axis=1)

df[["result_ats","spread"]] = df.Spread.str.split(" ", expand=True)
df["result"] = df.Score.str.split(" ", expand=True)[0]
df[["bears_pts","opp_pts"]] = df.Score.str.split(" ", expand=True)[1].str.split("-", expand=True)
df["num_spread"] = pd.to_numeric(df.spread)
df['score_diff'] = pd.to_numeric(df.bears_pts) - pd.to_numeric(df.opp_pts)
df["_opp"] = df.Opponent.str.lower().str.replace(" ", "-")
df["url"] = "https://raw.githubusercontent.com/kono10/notebooks/main/chicago_bears_nerd/data/nfl_logos/"+df._opp+".png"
df["home"] = np.where(df.away.eq("@"), "Away", "Home")

# %%
df
# Out:
#     Unnamed: 0  Week #  Day          Date Time (ET) away  \
# 0            0       1  Sun  Sep 12, 2021      8:20    @
# 1            1       2  Sun  Sep 19, 2021      1:00  NaN
# 2            2       3  Sun  Sep 26, 2021      1:00    @
# 3            3       4  Sun   Oct 3, 2021      1:00  NaN
# 4            4       5  Sun  Oct 10, 2021      4:04    @
# 5            5       6  Sun  Oct 17, 2021      1:00  NaN
# 6            6       7  Sun  Oct 24, 2021      4:25    @
# 7            7       8  Sun  Oct 31, 2021      1:00  NaN
# 8            8       9  Mon   Nov 8, 2021      8:15    @
# 9            9      11  Sun  Nov 21, 2021      1:00  NaN
# 10          10      12  Thu  Nov 25, 2021     12:30    @
# 11          11      13  Sun   Dec 5, 2021      1:00  NaN
# 12          12      14  Sun  Dec 12, 2021      8:20    @
# 13          13      15  Mon  Dec 20, 2021      8:15  NaN
# 14          14      16  Sun  Dec 26, 2021      4:04    @
# 15          15      17  Sun   Jan 2, 2022      1:00  NaN
# 16          16      18  Sun   Jan 9, 2022      1:00    @
#
#                 Opponent    Score   Spread   Total  ...  result_ats spread  \
# 0       Los Angeles Rams  L 14-34     L +8  O 46.5  ...           L     +8
# 1     Cincinnati Bengals  W 20-17   W -1.5  U 44.5  ...           W   -1.5
# 2       Cleveland Browns   L 6-26   L +7.5  U 44.5  ...           L   +7.5
# 3          Detroit Lions  W 24-14     W -3  U 41.5  ...           W     -3
# 4      Las Vegas Raiders   W 20-9   W +5.5  U 45.5  ...           W   +5.5
# 5      Green Bay Packers  L 14-24     L +6    U 44  ...           L     +6
# 6   Tampa Bay Buccaneers   L 3-38  L +11.5    U 47  ...           L  +11.5
# 7    San Francisco 49ers  L 22-33     L +4  O 39.5  ...           L     +4
# 8    Pittsburgh Steelers  L 27-29   W +6.5  O 38.5  ...           W   +6.5
# 9       Baltimore Ravens  L 13-16     W +5  U 43.5  ...           W     +5
# 10         Detroit Lions  W 16-14     L -3    U 41  ...           L     -3
# 11     Arizona Cardinals  L 22-33   L +7.5    O 42  ...           L   +7.5
# 12     Green Bay Packers  L 30-45  L +11.5    O 43  ...           L  +11.5
# 13     Minnesota Vikings   L 9-17   L +6.5  U 44.5  ...           L   +6.5
# 14      Seattle Seahawks  W 25-24   W +6.5  O 41.5  ...           W   +6.5
# 15       New York Giants   W 29-3   W -6.5  U 36.5  ...           W   -6.5
# 16     Minnesota Vikings  L 17-31     L +4  O 44.5  ...           L     +4
#
#    result bears_pts opp_pts num_spread  score_diff                  _opp  \
# 0       L        14      34        8.0         -20      los-angeles-rams
# 1       W        20      17       -1.5           3    cincinnati-bengals
# 2       L         6      26        7.5         -20      cleveland-browns
# 3       W        24      14       -3.0          10         detroit-lions
# 4       W        20       9        5.5          11     las-vegas-raiders
# 5       L        14      24        6.0         -10     green-bay-packers
# 6       L         3      38       11.5         -35  tampa-bay-buccaneers
# 7       L        22      33        4.0         -11   san-francisco-49ers
# 8       L        27      29        6.5          -2   pittsburgh-steelers
# 9       L        13      16        5.0          -3      baltimore-ravens
# 10      W        16      14       -3.0           2         detroit-lions
# 11      L        22      33        7.5         -11     arizona-cardinals
# 12      L        30      45       11.5         -15     green-bay-packers
# 13      L         9      17        6.5          -8     minnesota-vikings
# 14      W        25      24        6.5           1      seattle-seahawks
# 15      W        29       3       -6.5          26       new-york-giants
# 16      L        17      31        4.0         -14     minnesota-vikings
#
#                                                   url  home
# 0   https://raw.githubusercontent.com/kono10/noteb...  Away
# 1   https://raw.githubusercontent.com/kono10/noteb...  Home
# 2   https://raw.githubusercontent.com/kono10/noteb...  Away
# 3   https://raw.githubusercontent.com/kono10/noteb...  Home
# 4   https://raw.githubusercontent.com/kono10/noteb...  Away
# 5   https://raw.githubusercontent.com/kono10/noteb...  Home
# 6   https://raw.githubusercontent.com/kono10/noteb...  Away
# 7   https://raw.githubusercontent.com/kono10/noteb...  Home
# 8   https://raw.githubusercontent.com/kono10/noteb...  Away
# 9   https://raw.githubusercontent.com/kono10/noteb...  Home
# 10  https://raw.githubusercontent.com/kono10/noteb...  Away
# 11  https://raw.githubusercontent.com/kono10/noteb...  Home
# 12  https://raw.githubusercontent.com/kono10/noteb...  Away
# 13  https://raw.githubusercontent.com/kono10/noteb...  Home
# 14  https://raw.githubusercontent.com/kono10/noteb...  Away
# 15  https://raw.githubusercontent.com/kono10/noteb...  Home
# 16  https://raw.githubusercontent.com/kono10/noteb...  Away
#
# [17 rows x 21 columns]

# %%
chart_title = "Score Differential vs Game Spread 2021"
x_cfgs = {"shorthand":"num_spread", "title":"Spread"}
y_cfgs = {"shorthand":"score_diff", "title":"Score Diff"}
# background etc.
primary_color = "#0B162A" 
# font etc.
secondary_color = "#c83803"
axisLeftKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, labelFontSize=15, titleFontSize=17)
axisBottomKwargs = dict(labelColor=secondary_color, titleColor=secondary_color,labelFontSize=15, titleFontSize=17)
legendKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, strokeColor='gray', fillColor=primary_color, padding=10, cornerRadius=10,orient='top-right', labelFontSize=15, titleFontSize=15)

# %%
chart = alt.Chart(df, width=1500, height=1500, title=chart_title)\
.mark_image(height=50, width=50)\
.encode(
    x=alt.X(**x_cfgs,
        scale=alt.Scale(domain=[-38, 38], domainMid=0)

    ),
    y=alt.Y(**y_cfgs,
        scale=alt.Scale(domain=[-38, 38], domainMid=0)
    ),
    url="url",
    tooltip=[
        alt.Tooltip(shorthand="spread", title="Spread"),
        "Score",
        "Date",
        "Time (ET)",
        "Week #",
        alt.Tooltip(shorthand="home", title="Home/Away"),
        alt.Tooltip(shorthand="result_ats", title="Result Ats"),
    ]
)
df_mid = pd.DataFrame({'x': range(-38, 38), 'y': [i*-1 for i in range(-38, 38)]})


line = alt.Chart(df_mid).mark_line(color="white").encode(x="x", y="y")

(chart + line)\
.configure(background=primary_color)\
.configure_axis(gridColor="grey", gridDash=[6,4])\
.configure_axisLeft(**axisLeftKwargs)\
.configure_axisBottom(**axisBottomKwargs)\
.configure_title(color=secondary_color, fontSize=25)\
.configure_legend(**legendKwargs)
# Out:
# alt.LayerChart(...)

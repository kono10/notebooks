# %%
import pandas as pd

# %%
df = pd.read_csv("data/bears_2021_contract_info.csv")
df["contract_length"] = pd.to_numeric(df.contract_length)
df["contract_expires"] = df.contract_expires.replace("-", None)
df["contract_expires"] = pd.to_numeric(df.contract_expires)

# %%
df["contract_start"] = df.contract_expires - df.contract_length
df['_contract_amount'] = df.contract_amount.map('${:,.0f}'.format)

# %%
df
# Out:
#     Unnamed: 0        player_name position   age   exp  contract_amount  \
# 0            0       Robert Quinn       LB  32.0  12.0         70000000
# 1            1      Eddie Jackson       FS  29.0   6.0         58400000
# 2            2     Cody Whitehair        C  30.0   7.0         51250000
# 3            3      Justin Fields       QB  23.0   2.0         18871957
# 4            4       Roquan Smith       LB  25.0   5.0         18477168
# ..         ...                ...      ...   ...   ...              ...
# 86          86      LaCale London       DE  25.0   2.0           705000
# 87          87    Charles Snowden       DE  24.0   1.0           705000
# 88          88       Dazz Newsome       WR  23.0   1.0           660000
# 89          89  Thomas Graham Jr.       CB  23.0   1.0           660000
# 90          90         Sam Kamara       DT  24.0   2.0           660000
#
#     contract_length guaranteed_amount  contract_expires        acquired  \
# ...

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.sampledata.sprint import sprint
from bokeh.plotting import figure, show
from bokeh.layouts import gridplot
import bokeh.io

bokeh.io.reset_output()
bokeh.io.output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8968">Loading BokehJS ...</span>
#     </div>

# %%
df = df[df.contract_amount > 1000000]
source = ColumnDataSource(df.sort_values("contract_amount", ascending=True))
tooltips = [
    ("Player Name", "@player_name"),
    ("Position", "@position"),
    ("Experience (yrs)", "@exp"),
    ("Contract Amount", "@_contract_amount"),
    ("Guaranteed Amount", "@guaranteed_amount"),
    ("Contract Start", "@contract_start"),
    ("Contract Expires", "@contract_expires"),
    ("Acquired", "@acquired"),
]

p = figure(width=1500, 
           height=2000, title="Chicago Bears Contract Start and End Summary Sorted by Contract Amount", 
           x_range=(df.contract_start.min()-1, df.contract_expires.max()+1), y_range=df.player_name.tolist()[::-1],
           tooltips=tooltips,
          )
p.hbar(y="player_name", left='contract_start', right='contract_expires', height=0.4, source=source, fill_color="orange", line_color="black")
p.title.text_font_size = "25px"
p.min_border_top = 75
p.min_border_bottom = 75 

show(p)
# Out:
#   <div class="bk-root" id="3b59c123-d27f-4231-8153-2f86da56d095" data-root-id="9577"></div>

# %%
group

# %%
df

# %%
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.sampledata.sprint import sprint

df = sprint.copy()  # since we are modifying sampledata

df.Year = df.Year.astype(str)
group = df.groupby('Year')
source = ColumnDataSource(group)

p = figure(y_range=group, x_range=(9.5,12.7), width=400, height=550, toolbar_location=None,
           title="Time Spreads for Sprint Medalists (by Year)")
p.hbar(y="Year", left='Time_min', right='Time_max', height=0.4, source=source)

p.ygrid.grid_line_color = None
p.xaxis.axis_label = "Time (seconds)"
p.outline_line_color = None

show(p)
# Out:
#   <div class="bk-root" id="a94e8134-da3a-4b39-9419-605fece2713f" data-root-id="3323"></div>

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# player_name           object
# position              object
# age                  float64
# exp                  float64
# contract_amount        int64
# contract_length        int64
# guaranteed_amount     object
# contract_expires     float64
# acquired              object
# tm                    object
# contract_start       float64
# dtype: object

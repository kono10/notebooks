# %%
import altair as alt
import pandas as pd
import numpy as np
import warnings

# %%
df = pd.read_csv("nfl_weekly_betting_summary.csv")

# %%
df
# Out:
#     Unnamed: 0  Day          Date Time (ET) Unnamed: 4              Favorite  \
# 0            0  Thu   Sep 8, 2022      8:20        NaN         Buffalo Bills
# 1            1  Sun  Sep 11, 2022      1:00        NaN    New Orleans Saints
# 2            2  Sun  Sep 11, 2022      1:00          @     Carolina Panthers
# 3            3  Sun  Sep 11, 2022      1:00        NaN   San Francisco 49ers
# 4            4  Sun  Sep 11, 2022      1:00          @    Cincinnati Bengals
# ..         ...  ...           ...       ...        ...                   ...
# 89           9  Sun  Oct 16, 2022      4:04          @      Los Angeles Rams
# 90          10  Sun  Oct 16, 2022      4:04        NaN     Arizona Cardinals
# 91          11  Sun  Oct 16, 2022      4:25        NaN         Buffalo Bills
# 92          12  Sun  Oct 16, 2022      8:20          @   Philadelphia Eagles
# 93          13  Mon  Oct 17, 2022      8:15          @  Los Angeles Chargers
#
#            Score  Spread Unnamed: 8             Underdog Over/Under Notes  \
# 0        W 31-10  W -2.5          @     Los Angeles Rams       U 52   NaN
# 1        W 27-26  L -5.5          @      Atlanta Falcons     O 43.5   NaN
# 2        L 24-26  L -1.5        NaN     Cleveland Browns       O 42   NaN
# 3        L 10-19    L -6          @        Chicago Bears       U 38   NaN
# 4   L 20-23 (OT)    L -7        NaN  Pittsburgh Steelers       U 44   NaN
# ..           ...     ...        ...                  ...        ...   ...
# 89       W 24-10   W -10        NaN    Carolina Panthers     U 41.5   NaN
# 90        L 9-19  L -2.5          @     Seattle Seahawks     U 50.5   NaN
# 91       W 24-20  W -2.5          @   Kansas City Chiefs       U 54   NaN
# 92       W 26-17  W -6.5        NaN       Dallas Cowboys       O 42   NaN
# 93  W 19-16 (OT)  L -4.5        NaN       Denver Broncos     U 45.5   NaN
#
#     week
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
# ..   ...
# 89     6
# 90     6
# 91     6
# 92     6
# 93     6
#
# [94 rows x 13 columns]

# %%
df = df.rename({"Unnamed: 5":"away"}, axis=1)
df[["result_ats","spread"]] = df.Spread.str.split(" ", expand=True)

# %%
df["result"] = df.Score.str.split(" ", expand=True)[0]
df[["fav_pts","opp_pts"]] = df.Score.str.split(" ", expand=True)[1].str.split("-", expand=True)

# %%
df["num_spread"] = pd.to_numeric(df.spread)
df['score_diff'] = pd.to_numeric(df.opp_pts) - pd.to_numeric(df.fav_pts)

# %%
week = 6
chart_title = f"Week {week} Score Differential Vs Game Spread"
x_cfgs = {"shorthand":"matchup", "title":"Fav - Dog"}
y_cfgs = {"shorthand":"score_diff", "title":"Score Differential (Dog pts - Fav pts)"}
# background etc.
primary_color = "#0B162A" 
# font etc.
secondary_color = "#c83803"
axisLeftKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, labelFontSize=15, titleFontSize=17)
axisBottomKwargs = dict(labelColor=secondary_color, titleColor=secondary_color,labelFontSize=15, titleFontSize=17)
legendKwargs = dict(labelColor=secondary_color, titleColor=secondary_color, strokeColor='gray', fillColor=primary_color, padding=10, cornerRadius=10,orient='top-right', labelFontSize=15, titleFontSize=15)

# %%
team_map = {'Washington Commanders':"Was",
 'San Francisco 49ers':"49ers",
 'Cleveland Browns':"Cle",
 'Green Bay Packers':"GB",
 'Indianapolis Colts':"Ind",
 'Minnesota Vikings':"Min",
 'Cincinnati Bengals':"Cin",
 'Baltimore Ravens':"Bal",
 'Tampa Bay Buccaneers':"TB",
 'Los Angeles Rams':"Rams",
 'Arizona Cardinals':"Az",
 'Buffalo Bills':"Buf",
 'Philadelphia Eagles':"Phi",
 'Los Angeles Chargers':"Charges",
'Chicago Bears':"Chi",
'Atlanta Falcons':"Atl",
'New England Patriots':"NE",
'New York Jets':"Jets",
'Jacksonville Jaguars':"Jac",
'Miami Dolphins':"Mia",
'New Orleans Saints':"No",
'New York Giants':"Giants",
'Pittsburgh Steelers':"Pit",
'Carolina Panthers':"Car",
'Seattle Seahawks':"Sea",
'Kansas City Chiefs':"KC",
'Dallas Cowboys':"Dal",
'Denver Broncos':"Den"
}

# %%
df["fav_abr"] =  df.Favorite.map(team_map)
df["dog_abr"] = df.Underdog.map(team_map)

# %%
df["matchup"] = df.fav_abr + " - " + df.dog_abr

# %%
df
# Out:
#     Unnamed: 0  Day          Date Time (ET) Unnamed: 4               Favorite  \
# 80           0  Thu  Oct 13, 2022      8:15        NaN  Washington Commanders
# 81           1  Sun  Oct 16, 2022      1:00        NaN    San Francisco 49ers
# 82           2  Sun  Oct 16, 2022      1:00          @       Cleveland Browns
# 83           3  Sun  Oct 16, 2022      1:00          @      Green Bay Packers
# 84           4  Sun  Oct 16, 2022      1:00          @     Indianapolis Colts
# 85           5  Sun  Oct 16, 2022      1:00        NaN      Minnesota Vikings
# 86           6  Sun  Oct 16, 2022      1:00        NaN     Cincinnati Bengals
# 87           7  Sun  Oct 16, 2022      1:00        NaN       Baltimore Ravens
# 88           8  Sun  Oct 16, 2022      1:00        NaN   Tampa Bay Buccaneers
# 89           9  Sun  Oct 16, 2022      4:04          @       Los Angeles Rams
# 90          10  Sun  Oct 16, 2022      4:04        NaN      Arizona Cardinals
# 91          11  Sun  Oct 16, 2022      4:25        NaN          Buffalo Bills
# 92          12  Sun  Oct 16, 2022      8:20          @    Philadelphia Eagles
# 93          13  Mon  Oct 17, 2022      8:15          @   Los Angeles Chargers
#
#            Score  Spread Unnamed: 8              Underdog  ... result_ats  \
# 80        W 12-7    W -1          @         Chicago Bears  ...          W
# 81       L 14-28  L -4.5          @       Atlanta Falcons  ...          L
# 82       L 15-38  L -2.5        NaN  New England Patriots  ...          L
# 83       L 10-27  L -7.5        NaN         New York Jets  ...          L
# 84       W 34-27  W -1.5        NaN  Jacksonville Jaguars  ...          W
# 85       W 24-16    W -3          @        Miami Dolphins  ...          W
# 86       W 30-26    W -3          @    New Orleans Saints  ...          W
# 87       L 20-24  L -5.5          @       New York Giants  ...          L
# 88       L 18-20  L -9.5          @   Pittsburgh Steelers  ...          L
# 89       W 24-10   W -10        NaN     Carolina Panthers  ...          W
# 90        L 9-19  L -2.5          @      Seattle Seahawks  ...          L
# 91       W 24-20  W -2.5          @    Kansas City Chiefs  ...          W
# 92       W 26-17  W -6.5        NaN        Dallas Cowboys  ...          W
# 93  W 19-16 (OT)  L -4.5        NaN        Denver Broncos  ...          L
#
#    spread  result fav_pts opp_pts num_spread score_diff        matchup  \
# 80     -1       W      12       7       -1.0         -5      Was - Chi
# 81   -4.5       L      14      28       -4.5         14    49ers - Atl
# 82   -2.5       L      15      38       -2.5         23       Cle - NE
# 83   -7.5       L      10      27       -7.5         17      GB - Jets
# 84   -1.5       W      34      27       -1.5         -7      Ind - Jac
# 85     -3       W      24      16       -3.0         -8      Min - Mia
# 86     -3       W      30      26       -3.0         -4       Cin - No
# 87   -5.5       L      20      24       -5.5          4   Bal - Giants
# 88   -9.5       L      18      20       -9.5          2       TB - Pit
# 89    -10       W      24      10      -10.0        -14     Rams - Car
# 90   -2.5       L       9      19       -2.5         10       Az - Sea
# 91   -2.5       W      24      20       -2.5         -4       Buf - KC
# 92   -6.5       W      26      17       -6.5         -9      Phi - Dal
# 93   -4.5       W      19      16       -4.5         -3  Charges - Den
#
#     fav_abr  dog_abr
# 80      Was      Chi
# 81    49ers      Atl
# 82      Cle       NE
# 83       GB     Jets
# 84      Ind      Jac
# 85      Min      Mia
# 86      Cin       No
# 87      Bal   Giants
# 88       TB      Pit
# 89     Rams      Car
# 90       Az      Sea
# 91      Buf       KC
# 92      Phi      Dal
# 93  Charges      Den
#
# [14 rows x 23 columns]

# %%
chart = alt.Chart(df[df.week.eq(week)], width=800, height=500, title=chart_title)\
.mark_bar()\
.encode(
    x=alt.X(**x_cfgs,),
    y=alt.Y(**y_cfgs,
    ),
    tooltip=[
        #alt.Tooltip(shorthand="spread", title="Spread"),
        "Date",
        "Time (ET)",
        "Day",
        "Favorite",
        "Underdog",
        "Over/Under",
        "Spread",
        "Score"
    ],
    color=alt.condition(
        alt.datum.score_diff - alt.datum.num_spread > 0,
        alt.value(secondary_color),  # The positive color
        alt.value("white")  # The negative color
    ),
)


tick = alt.Chart(df).mark_tick(
    color='red',
    width=50,
    thickness=5,
    size=40 * 0.9,  # controls width of tick.
).encode(
    x=alt.X(**x_cfgs,),
    y='num_spread'
)

(chart + tick)\
.configure(background=primary_color)\
.configure_axis(gridColor="grey", gridDash=[6,4])\
.configure_axisLeft(**axisLeftKwargs)\
.configure_axisBottom(**axisBottomKwargs)\
.configure_title(color=secondary_color, fontSize=25)\
.configure_legend(**legendKwargs)#.save("chart.json")
# Out:
# alt.LayerChart(...)

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/jkonovsky/development/notebooks/chicago_bears_nerd/visuals/weekly_charts'

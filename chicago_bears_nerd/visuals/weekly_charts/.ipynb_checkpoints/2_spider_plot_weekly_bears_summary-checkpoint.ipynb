# %%
import os
import glob
import altair as alt
import pandas as pd
import numpy as np
import warnings
from plotly.subplots import make_subplots
import plotly.graph_objects as go
from pathlib import Path
import os
import plotly

pd.set_option('display.max_rows', 500)

# %%
team = "Chicago Bears"
team_city = "Chicago"
team_underscore = "_".join(team.lower().split(" "))

team_opp = "Miami Dolphins"
team_opp_alt = team_opp
team_city_opp = "Miami"
team_opp_underscore = "_".join(team_opp.lower().split(" "))

team_date = "20221102"
player_date = "20221102"
nfl_date = "20221102"
# bears
# background etc.
primary_color = "#0B162A" 
secondary_color = "#C83803"

opp_primary_color = "#008E97" 
opp_secondary_color = "#FC4C02"

path_base = Path(os.getcwd()).parents[1]

print(path_base)
# Out:
# /home/jkonovsky/development/notebooks/chicago_bears_nerd

# %%
cols = ["Date", "Opponent", "Result", "W/L", "Div", "Spread", "Total", "Money"]
df_schedule = pd.read_csv(f"{path_base}/data/team_ranks/_nfl_team_{team_underscore}__{team_date}.csv")
df_schedule["Opponent"] = np.where(df_schedule.Location.eq("Away"), "@" + df_schedule.Opponent, df_schedule.Opponent)
record_str = df_schedule[~df_schedule.Div.isnull()].iloc[-1]["W/L"]

# %%
df_schedule = df_schedule.fillna("")
df_schedule = df_schedule.head(n=10)[cols]

df_schedule_opp = pd.read_csv(f"{path_base}/data/team_ranks/_nfl_team_{team_opp_underscore}__{team_date}.csv")
df_schedule_opp["Opponent"] = np.where(df_schedule_opp.Location.eq("Away"), "@" + df_schedule_opp.Opponent, df_schedule_opp.Opponent)
record_opp_str = df_schedule_opp[~df_schedule_opp.Div.isnull()].iloc[-1]["W/L"]

df_schedule_opp = df_schedule_opp.fillna("")
df_schedule_opp = df_schedule_opp.head(n=10)[cols]

# %%
file_path = f"{path_base}/data/team_ranks/_nfl_player_stat_*{team_date}.csv"
file_paths = glob.glob(os.path.join(file_path))

pds = list()
for file_path in file_paths:
    print(file_path)
    df = pd.read_csv(file_path)
    pds.append(df)
_df_player = pd.concat(pds)
# Out:
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_games_played_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_games_started_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_quarterback_wins_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_quarterback_losses_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_quarterback_ties_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_quarterback_winning_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_plays_completed_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_plays_attempted_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_gross_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_touchdown_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_plays_intercepted_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_interception_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_games_with_an_interception_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_percent_of_games_with_an_interception_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_completion_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_gross_yards_per_passing_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_plays_sacked_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_sacked_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_net_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_net_yards_per_passing_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_qb_rating_nfl_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_passing_2pt_conversions_succeeded_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_and_receiving_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_plays_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_net_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_yards_per_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_2pt_conversions_succeeded_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_rushing_and_receiving_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_receptions_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_yards_per_catch_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_targeted_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_catch_rate_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_receiving_2pt_conversions_succeeded_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_returns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_return_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_return_yards_per_return_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_return_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_return_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kickoff_return_faircatches_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_returns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_return_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_return_yards_per_return_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_return_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_return_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punt_return_faircatches_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_fumbles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_fumbles_lost_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_miscellaneous_fumble_recoveries_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_longest_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_extra_point_kicks_succeeded_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_extra_point_kicks_attempted_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_extra_point_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_0_to_19_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_0_to_19_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_0_to_19_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_20_to_29_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_20_to_29_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_20_to_29_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_30_to_39_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_30_to_39_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_30_to_39_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_40_to_49_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_40_to_49_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_40_to_49_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_succeeded_50_plus_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goals_attempted_50_plus_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_field_goal_percentage_50_plus_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_kicking_points_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_plays_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_gross_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_yards_per_punt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_inside_twenty_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_inside_twenty_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_touchbacks_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_punting_touchback_percentage_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_total_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_solo_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_assisted_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_sacks_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_sack_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_tackles_for_loss_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_pass_defenses_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_interceptions_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_interception_yards_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_interceptions_returned_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_forced_fumbles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_fumble_recoveries_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_fumbles_recovered_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_fumbles_recovered_lost_by_opposition_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_special_teams_total_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_special_teams_solo_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_special_teams_assisted_tackles_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_defense_special_teams_fumble_recoveries_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_total_touchdowns_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_games_with_a_touchdown_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_percent_of_games_with_a_touchdown_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_scoring_two_point_conversions_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_scoring_field_goals_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_scoring_extra_points_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_player_stat_scoring_total_points_20221102.csv

# %%
_df_player
# Out:
#     Unnamed: 0  Rank              Player                  Team Pos Value  \
# 0            0     1         Bryan Anger        Dallas Cowboys   P    83
# 1            1     2     Corey Bojorquez      Cleveland Browns   P    76
# 2            2     3      Tommy Townsend    Kansas City Chiefs   P    74
# 3            3     3    Mitch Wishnowsky   San Francisco 49ers   P    74
# 4            4     5      Bradley Pinion       Atlanta Falcons   P    73
# ..         ...   ...                 ...                   ...  ..   ...
# 95          95    82  Alexander Mattison     Minnesota Vikings  RB    18
# 96          96    82    Daniel Bellinger       New York Giants  TE    18
# 97          97    82       Chase Edmonds        Miami Dolphins  RB    18
# 98          98    82       Jakobi Meyers  New England Patriots  WR    18
# 99          99    82         Romeo Doubs     Green Bay Packers  WR    18
#
#                           asof                                     url
# 0   2022-11-01 08:10:22.229268  /nfl/player-stat/punting-longest-yards
# 1   2022-11-01 08:10:22.229268  /nfl/player-stat/punting-longest-yards
# 2   2022-11-01 08:10:22.229268  /nfl/player-stat/punting-longest-yards
# 3   2022-11-01 08:10:22.229268  /nfl/player-stat/punting-longest-yards
# 4   2022-11-01 08:10:22.229268  /nfl/player-stat/punting-longest-yards
# ..                         ...                                     ...
# 95  2022-11-01 08:10:45.173589   /nfl/player-stat/scoring-total-points
# 96  2022-11-01 08:10:45.173589   /nfl/player-stat/scoring-total-points
# 97  2022-11-01 08:10:45.173589   /nfl/player-stat/scoring-total-points
# 98  2022-11-01 08:10:45.173589   /nfl/player-stat/scoring-total-points
# 99  2022-11-01 08:10:45.173589   /nfl/player-stat/scoring-total-points
#
# [10128 rows x 8 columns]

# %%
cols = ["Player", "Pos", "Rank", "Stat", "Value"]

player_stats_list = ["passing-gross-yards", "passing-touchdowns", "rushing-net-yards", "rushing-touchdowns", "defense-total-tackles", "defense-sacks"]
_df_player["_stat"] = _df_player.url.str.split("/", expand=True)[3]
_df_player["Stat"] = _df_player._stat.str.split("-").str.join(" ").str.title()
_df_player = _df_player[_df_player._stat.isin(player_stats_list)]
_df_player["Stat"] = _df_player.Stat.str.replace("Per Game", "Pg").str.replace("Opponent", "Opp")\
.str.replace("Offensive", "Off")\
.str.replace("Defensive", "Def")\
.str.replace("Touchdowns", "Td")\
.str.replace("Rushing", "Run")\
.str.replace("Passing", "Pass")\
.str.replace("Total", "")\
.str.replace("Defense", "")\
.str.replace("Gross", "")\
.str.replace("Net", "")
_df_player["Value"] = pd.to_numeric(_df_player.Value)
_df_player = _df_player[_df_player.Value.gt(0)]

df_player = _df_player[_df_player.Team.eq(team)][cols]
df_player_opp = _df_player[_df_player.Team.eq(team_opp)][cols]
# Out:
# /tmp/ipykernel_1113847/3056669376.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df_player["Stat"] = _df_player.Stat.str.replace("Per Game", "Pg").str.replace("Opponent", "Opp")\
# /tmp/ipykernel_1113847/3056669376.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   _df_player["Value"] = pd.to_numeric(_df_player.Value)

# %%
file_path = f"{path_base}/data/team_ranks/_nfl_stat*{nfl_date}.csv"
file_paths = glob.glob(os.path.join(file_path))
pds = list()
for file_path in file_paths:
    print(file_path)
    df = pd.read_csv(file_path)
    pds.append(df)
df = pd.concat(pds)
# Out:
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_average_scoring_margin_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_point_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_point_margin_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_points_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_points_per_play_margin_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_red_zone_scoring_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_red_zone_scores_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_red_zone_scoring_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_extra_point_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_extra_points_made_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_two_point_conversion_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_two_point_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_points_per_field_goal_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_extra_point_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_two_point_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_offensive_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_defensive_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_special_teams_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_offensive_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_defensive_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_special_teams_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_offensive_point_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_1st_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_2nd_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_3rd_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_4th_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_overtime_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_1st_half_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_2nd_half_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_1st_quarter_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_2nd_quarter_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_3rd_quarter_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_4th_quarter_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_1st_half_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_2nd_half_time_of_possession_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_plays_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_third_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_third_down_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fourth_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fourth_down_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_average_time_of_possession_net_of_ot_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_time_of_possession_pct_net_of_ot_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_seconds_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_first_downs_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_third_down_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fourth_down_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punts_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punts_per_offensive_score_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_solo_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_assisted_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_rush_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_play_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_touchdown_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_first_down_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_rushing_yards_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_pass_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_completions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_incompletions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_completion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_gross_passing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_pass_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_yards_per_completion_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_touchdown_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_qb_sacked_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_qb_sacked_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_first_down_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_average_team_passer_rating_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_play_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_passing_yards_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_other_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goal_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goals_made_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goals_got_blocked_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_kicking_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punt_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punts_got_blocked_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_gross_punt_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_net_punt_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_kickoffs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_touchbacks_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_kickoff_touchback_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goal_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goal_got_blocked_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goal_conversion_pct_net_of_blocks_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punt_blocked_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_net_yards_per_punt_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_gross_yards_per_successful_punt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_net_yards_per_successful_punt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_yards_per_point_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_points_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_red_zone_scoring_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_red_zone_scores_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_red_zone_scoring_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_extra_point_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_extra_points_made_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_two_point_conversion_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_two_point_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_points_per_field_goal_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_extra_point_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_two_point_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_offensive_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_defensive_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_special_teams_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_offensive_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_defensive_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_special_teams_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_offensive_point_share_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_1st_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_2nd_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_3rd_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_4th_quarter_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opp_overtime_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_1st_half_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_2nd_half_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_plays_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_yards_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_third_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_third_down_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fourth_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fourth_down_conversions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_average_time_of_possession_net_of_ot_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_time_of_possession_pct_net_of_ot_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_seconds_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_first_downs_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_third_down_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fourth_down_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_punts_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_punts_per_offensive_score_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_solo_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_assisted_tackles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_yards_per_rush_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_play_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_touchdown_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_first_down_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_rushing_yards_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_pass_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_completions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_incompletions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_completion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_gross_passing_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_yards_per_pass_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_yards_per_completion_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_touchdown_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_average_team_passer_rating_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_sack_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_play_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_yards_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_sacks_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_passing_first_down_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_other_touchdowns_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_field_goal_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_field_goals_made_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_field_goals_blocked_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_kicking_points_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_punt_attempts_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_punts_blocked_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_gross_punt_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_net_punt_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_kickoffs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_touchbacks_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_kickoff_touchback_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_field_goal_conversion_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_block_field_goal_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_field_goal_conversion_pct_net_of_blocks_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_block_punt_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_net_yards_per_punt_attempt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_gross_yards_per_successful_punt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_net_yards_per_successful_punt_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_interceptions_thrown_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_percent_of_games_with_an_interception_thrown_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fumbles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fumbles_lost_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fumbles_not_lost_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_safeties_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_giveaways_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_turnover_margin_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_interceptions_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_percent_of_games_with_an_interception_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fumbles_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fumbles_lost_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fumbles_not_lost_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_safeties_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_takeaways_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_pass_intercepted_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_giveaway_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_takeaway_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_interception_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_giveaway_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_takeaway_fumble_recovery_pct_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_penalties_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_penalty_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_penalty_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_penalties_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_penalty_yards_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_penalty_first_downs_per_game_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_penalty_yards_per_penalty_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_penalties_per_play_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_penalty_yards_per_penalty_20221102.csv
# /home/jkonovsky/development/notebooks/chicago_bears_nerd/data/team_ranks/_nfl_stat_opponent_penalties_per_play_20221102.csv

# %%
def_stats = {
    "opponent-points-per-game":.6,
    "opponent-points-per-play":1,
    "opponent-1st-half-points-per-game":1.5,
    "opponent-2nd-half-points-per-game":1.6,
    "opponent-rushing-touchdowns-per-game":1.7,
    "opponent-passing-touchdowns-per-game":1.8,
    "opponent-yards-per-game":1.85,
    "opponent-yards-per-play":1.9,
    "opponent-rushing-yards-per-game":2,
    "opponent-yards-per-rush-attempt":2.1,
    "opponent-passing-yards-per-game":2.6,
    "opponent-yards-per-pass-attempt":3,
    "defensive-points-per-game":4,
    "sacks-per-game":10,
    "interceptions-per-game":11,
    "opponent-fumbles-per-game":12,
    }


stats = {
    "points-per-game":2,
    "points-per-play":3.5,
    "1st-half-points-per-game":3.9,
    "2nd-half-points-per-game":4,
    "rushing-touchdowns-per-game":4.1,
    "passing-touchdowns-per-game":4.2,
    "yards-per-game":4.5,
    "yards-per-play":4.8,
    "rushing-yards-per-game":4.9,
    "yards-per-rush-attempt":5,
    "rushing-play-pct":5.5,
    "passing-yards-per-game":5.6,
    "yards-per-pass-attempt":6,
    "passing-play-pct":7,
    "qb-sacked-per-game":10,
    "interceptions-thrown-per-game":11,
    "fumble-per-game":12,
    "penalties-per-game":13
    }

df["_stat"] = df.url.str.split("/", expand=True)[3]
df["Stat"] = df._stat.str.split("-").str.join(" ").str.title()
df["Stat"] = df.Stat.str.replace("Per Game", "Pg").str.replace("Opponent", "Opp")\
.str.replace("Offensive", "Off")\
.str.replace("Defensive", "Def")\
.str.replace("Touchdowns", "Td")\
.str.replace("Rushing", "Run")\
.str.replace("Passing", "Pass")\
.str.replace("Interceptions", "Int")

# %%
def generate_off_def_df(dft, gstats=stats):
    dft["_order"] = dft._stat.map(gstats)
    dfp = dft[dft._stat.isin(gstats)]
    dfp_opp = dfp[dfp.Team.eq(team_city_opp)].sort_values("_order")
    dfp = dfp[dfp.Team.eq(team_city)].sort_values("_order")
    return dfp, dfp_opp

def generate_spider(df, primarycolor, plot_name, custom_data_columns=["2021", "2022"], visible=True):
    return go.Scatterpolar(
    r=df.Rank.tolist(),
    theta=df.Stat.tolist(),
    visible=visible,
    fill='toself',
    customdata=df[custom_data_columns],
    hovertemplate = "Stat: %{theta} <br> Rank: %{r} <br> 2022: %{customdata[0]} <br> 2021: %{customdata[1]} <extra></extra>",
    hoverlabel=dict(bgcolor=primarycolor, font_size=16, font_color="#A5ACAF"),
    name=plot_name,
    marker=dict(color=primarycolor, size=10,line=dict(width=2))
)

def generate_table(df, header_color, background_color, sel_cols=["Stat", "Rank", "2022", "2021"], columnwidth=[.40, .2, .2, .2], visible=True):
    if sel_cols is not None:
        df = df[sel_cols]
    return go.Table(
        header=dict(values=df.columns, fill_color=header_color, font_color="white"), 
        columnwidth=columnwidth, visible=visible,
        cells=dict(values=df.T.values, fill_color=background_color, font_color="white", height=35, align=["left", "center"])
    )

# %%
df_plot_def, df_plot_opp_def = generate_off_def_df(df, def_stats)
df_plot, df_plot_opp = generate_off_def_df(df, stats)
week = df_schedule[df_schedule.Opponent.str.contains(team_city_opp)].index.max()+1



fig = make_subplots(rows=4, cols=2, 
                    row_heights=[.39, .27, .17, .28], 
                    horizontal_spacing=.02, 
                    vertical_spacing=.02,
                    specs=[
                        [{"colspan": 2, "type":"scatterpolar"}, None],
                        [{"type":"table"}, {"type":"table"}],
                        [{"type":"table"}, {"type":"table"}],
                        [{"type":"table"}, {"type":"table"}],
                    ]
                   )

opp_color = opp_primary_color
sel_cols = ["Stat", "Rank", "2022", "Last 1", "Last 3", "2021"]

scat = generate_spider(df_plot, primarycolor=secondary_color, plot_name=team)
scat_opp = generate_spider(df_plot_opp, primarycolor=opp_primary_color, plot_name=team_opp)
scat_def = generate_spider(df_plot_def, primarycolor=secondary_color, plot_name=team, visible=False)
scat_opp_def = generate_spider(df_plot_opp_def, primarycolor=opp_primary_color, plot_name=team_opp, visible=False)

table = generate_table(df_plot, header_color=secondary_color, background_color=primary_color, sel_cols=sel_cols)
table_opp = generate_table(df_plot_opp,  header_color=opp_secondary_color, background_color=opp_primary_color, sel_cols=sel_cols)

table_def = generate_table(df_plot_def,  header_color=secondary_color, background_color=primary_color, visible=False, sel_cols=sel_cols)
table_opp_def = generate_table(df_plot_opp_def,  header_color=opp_secondary_color, background_color=opp_primary_color, visible=False, sel_cols=sel_cols)

table_schedule = generate_table(df_schedule, header_color=secondary_color, background_color=primary_color, columnwidth=[.2, .35, .22, .2], sel_cols=None)
table_player = generate_table(df_player, header_color=secondary_color, background_color=primary_color, columnwidth=[.4, .2, .2, .2], sel_cols=None)

table_opp_schedule = generate_table(df_schedule_opp,  header_color=opp_secondary_color, background_color=opp_primary_color, columnwidth=[.2, .35, .22, .2], sel_cols=None)
table_opp_player = generate_table(df_player_opp,  header_color=opp_secondary_color, background_color=opp_primary_color, columnwidth=[.4, .2, .2, .2], sel_cols=None)



fig.add_trace(scat)
fig.add_trace(scat_opp)

fig.add_trace(scat_def)
fig.add_trace(scat_opp_def)

fig.add_trace(table, row=2, col=1)
fig.add_trace(table_opp, row=2, col=2)

fig.add_trace(table_def, row=2, col=1)
fig.add_trace(table_opp_def, row=2, col=2)


fig.add_trace(table_schedule, row=3, col=1)
fig.add_trace(table_player, row=4, col=1)

fig.add_trace(table_opp_schedule, row=3, col=2)
fig.add_trace(table_opp_player, row=4, col=2)


updatemenus = [{'buttons': [{'method': 'update',
  'label': 'Offense',
  'visible': True,
  'args': [{'visible': [True, True, False, False, True, True, False, False, True, True, True, True]}
          ]},
 {'method': 'update',
  'label': 'Defense',
  'visible': True,
  'args': [{'visible': [False, False, True, True, False, False, True, True, True, True, True, True], "execute":False}
          ]}
],
                'active':0,
                'direction': 'down',
                'showactive': False,
                "pad":{"r": 5, "t": 20},
                "xanchor":"left",
                "yanchor":"bottom",
                "x":.85,
                "y":.99,
                "font_size":35,
                "bgcolor":primary_color,
                "bordercolor":secondary_color,
                "borderwidth":5,
               }
]


fig.update_layout(
    title= f"<b>{team} {record_str} vs {team_opp} {record_opp_str} Week {week} Matchup </b>",
    font_family="Times New Roman",
    updatemenus=updatemenus,
    height=3000,
    margin=dict(
        l=5,
        r=5,
    ),
    showlegend=True,
    title_font_size=35,
    legend_title="Rank",
    font_size = 20,
    legend=dict(yanchor="top",y=0.96,xanchor="left", x=0.85),

    font=dict(color=secondary_color),
    polar = dict(
      bgcolor = primary_color,
      angularaxis = dict(linewidth = 3, showline=True, gridcolor = "grey", linecolor="grey"),
      radialaxis = dict(side = "counterclockwise", showline = True, linewidth = 2, gridcolor = "grey", gridwidth = 2, dtick=5, autorange="reversed"),        
    ),
    paper_bgcolor = primary_color
)

# dont think this works correctly
#fig.to_json("chart_foo.json")

plotly.io.write_json(fig, "chart_json/spider.json")
fig.show()

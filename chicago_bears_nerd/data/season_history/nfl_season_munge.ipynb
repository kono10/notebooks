# %%
import pandas as pd
import pathlib
import os

# %%
path = "/home/jkonovsky/development/notebooks/chicago_bears_nerd/data/season_history/"

# %%
currentDir = pathlib.Path(path)
pd_list = []

# %%
for file_path in currentDir.iterdir():
    if file_path.name.endswith("xls"):
        season_year = file_path.name.replace(".xls","")
        df = pd.read_html(file_path)[0]
        df["season_year"] = season_year
        pd_list.append(df)
df_all = pd.concat(pd_list)

# %%
df = df_all[df_all.Date != "Playoffs"]

# %%
df
# Out:
#           Week  Day        Date    Time          Winner/tie Unnamed: 5  \
# 0            1  Thu  2020-09-10  8:20PM  Kansas City Chiefs        NaN
# 1            1  Sun  2020-09-13  1:00PM    Seattle Seahawks          @
# 2            1  Sun  2020-09-13  1:00PM       Buffalo Bills        NaN
# 3            1  Sun  2020-09-13  1:00PM   Las Vegas Raiders          @
# 4            1  Sun  2020-09-13  1:00PM       Chicago Bears          @
# ..         ...  ...         ...     ...                 ...        ...
# 281   Division  Sun  2022-01-23  3:00PM    Los Angeles Rams          @
# 282   Division  Sun  2022-01-23  6:30PM  Kansas City Chiefs        NaN
# 283  ConfChamp  Sun  2022-01-30  3:00PM  Cincinnati Bengals          @
# 284  ConfChamp  Sun  2022-01-30  6:30PM    Los Angeles Rams        NaN
# 285  SuperBowl  Sun  2022-02-13  6:30PM    Los Angeles Rams          N
#
#                 Loser/tie Unnamed: 7   Pts  Pts.1   YdsW  TOW   YdsL  TOL  \
# ...

# %%
output_path = os.path.join(path, "nfl_season_history.csv")

# %%
df_all.to_csv(output_path)

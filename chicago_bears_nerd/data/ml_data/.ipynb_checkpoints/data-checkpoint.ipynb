# %%
from bs4 import BeautifulSoup
import requests as req
from time import sleep
import pandas as pd
import os
import time
from datetime import datetime as dt
from tqdm import tqdm
#from tqdm import tqdm


# configure pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 "
        "(KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36"
    )
}

# %% [markdown]
# ## Rank Data
# ____

# %%
date = "2022-10-26"
week = 7
url = "https://www.teamrankings.com/nfl/stats/"
page = req.get(url, headers=headers).text
soup = BeautifulSoup(page, "html.parser")
pbar = tqdm([a["href"] for a in soup.find(attrs={"class":"column large-2"}).find_all("a") if a["href"] != "#"])
pd_list = []
for end_point in pbar:
    time.sleep(.25)
    url = f"https://www.teamrankings.com{end_point}?date={date}"
    page = req.get(url, headers=headers).text
    soup = BeautifulSoup(page, "html.parser")
    table = soup.find("table")
    df = pd.read_html(str(table))[0].replace("--",0)
    df["asof"] = date
    df["url"] = end_point
    file_name = end_point.replace('/', '_').replace("-","_") + "_week" + str(week)
    pbar.set_description(end_point)
    pd_list.append(df)
    
full_file_path = f"/rank_data_week_{week}.csv"
pd.concat(pd_list).to_csv(f"{full_file_path}.csv")
print(df.head())
# Out:
# /nfl/stat/yards-per-point-margin:   2%|▏         | 4/226 [00:04<04:13,  1.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-b5bfdea1a0b8> in <module>
#       9     time.sleep(.25)
#      10     url = f"https://www.teamrankings.com{end_point}?date={date}"
# ---> 11     page = req.get(url, headers=headers).text
#      12     soup = BeautifulSoup(page, "html.parser")
#      13     table = soup.find("table")
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /usr/local/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     685
#     686         if not stream:
# --> 687             r.content
#     688
#     689         return r
#
# /usr/local/lib/python3.6/site-packages/requests/models.py in content(self)
#     836                 self._content = None
#     837             else:
# --> 838                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     839
#     840         self._content_consumed = True
#
# /usr/local/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# /usr/local/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     621         """
#     622         if self.chunked and self.supports_chunked_reads():
# --> 623             for line in self.read_chunked(amt, decode_content=decode_content):
#     624                 yield line
#     625         else:
#
# /usr/local/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     816                 if self.chunk_left == 0:
#     817                     break
# --> 818                 chunk = self._handle_chunk(amt)
#     819                 decoded = self._decode(
#     820                     chunk, decode_content=decode_content, flush_decoder=False
#
# /usr/local/lib/python3.6/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     770         else:  # amt > self.chunk_left
#     771             returned_chunk = self._fp._safe_read(self.chunk_left)
# --> 772             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     773             self.chunk_left = None
#     774         return returned_chunk
#
# /usr/local/lib/python3.6/http/client.py in _safe_read(self, amt)
#     628         s = []
#     629         while amt > 0:
# --> 630             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     631             if not chunk:
#     632                 raise IncompleteRead(b''.join(s), amt)
#
# /usr/local/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/local/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/local/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/local/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Spread and Game Data
# ___

# %%
url = f"https://www.sportsoddshistory.com/nfl-game-season/?y=2022"
page = req.get(url, headers=headers).text
soup = BeautifulSoup(page, "html.parser")
tables = soup.find_all("table", attrs={"class":"soh1"})
pd_list = []
for i, table in enumerate(tables[2:]):
    df = pd.read_html(str(table))
    df = df[0]
    df.columns = df.iloc[-2]
    df = df.iloc[:-2,: ]
    df["week"] = i + 1
    pd_list.append(df)
df = pd.concat(pd_list)
print(df.head())
df.to_csv("data/nfl_weekly_betting_summary.csv")
df.to_csv("data/ml_data/nfl_weekly_betting_summary.csv")

# %%
df_games = pd.read_csv("nfl_weekly_betting_summary.csv")
df_ranks = pd.read_csv("rank_data_week_8.csv")

# %%
df_games.head()
# Out:
#    Unnamed: 0  Day          Date Time (ET) Unnamed: 4             Favorite         Score  Spread Unnamed: 8             Underdog Over/Under Notes  week
# 0           0  Thu   Sep 8, 2022      8:20        NaN        Buffalo Bills       W 31-10  W -2.5          @     Los Angeles Rams       U 52   NaN     1
# 1           1  Sun  Sep 11, 2022      1:00        NaN   New Orleans Saints       W 27-26  L -5.5          @      Atlanta Falcons     O 43.5   NaN     1
# 2           2  Sun  Sep 11, 2022      1:00          @    Carolina Panthers       L 24-26  L -1.5        NaN     Cleveland Browns       O 42   NaN     1
# 3           3  Sun  Sep 11, 2022      1:00        NaN  San Francisco 49ers       L 10-19    L -6          @        Chicago Bears       U 38   NaN     1
# 4           4  Sun  Sep 11, 2022      1:00          @   Cincinnati Bengals  L 20-23 (OT)    L -7        NaN  Pittsburgh Steelers       U 44   NaN     1

# %%
df_games["fav_pts"] = df_games.Score.str.split(" ", expand=True)[1].str.split("-", expand=True)[0]
df_games["dog_pts"] = df_games.Score.str.split(" ", expand=True)[1].str.split("-", expand=True)[1]
df_fav = df_games[["Date", "Time (ET)", "Favorite", "Underdog", "Score", "week", "fav_pts"]].rename(columns={"Favorite":"Team", 
                                                                                                 "fav_pts":"team_pts_scored", 
                                                                                                 "Underdog":"Opp",
                                                                                                })

# %%
df_opp = df_games[["Date", "Time (ET)", "Favorite", "Underdog", "Score", "week", "dog_pts"]].rename(columns={"Underdog":"Team", 
                                                                                                 "dog_pts":"team_pts_scored",
                                                                                                 "Favorite":"Opp"
                                                                                                })
df_games = pd.concat([df_fav, df_opp])

# %%
df_games
# Out:
#              Date Time (ET)                   Team                    Opp         Score  week team_pts_scored
# 0     Sep 8, 2022      8:20          Buffalo Bills       Los Angeles Rams       W 31-10     1              31
# 1    Sep 11, 2022      1:00     New Orleans Saints        Atlanta Falcons       W 27-26     1              27
# 2    Sep 11, 2022      1:00      Carolina Panthers       Cleveland Browns       L 24-26     1              24
# 3    Sep 11, 2022      1:00    San Francisco 49ers          Chicago Bears       L 10-19     1              10
# 4    Sep 11, 2022      1:00     Cincinnati Bengals    Pittsburgh Steelers  L 20-23 (OT)     1              20
# 5    Sep 11, 2022      1:00    Philadelphia Eagles          Detroit Lions       W 38-35     1              38
# 6    Sep 11, 2022      1:00     Indianapolis Colts         Houston Texans  T 20-20 (OT)     1              20
# 7    Sep 11, 2022      1:00         Miami Dolphins   New England Patriots        W 20-7     1              20
# 8    Sep 11, 2022      1:00       Baltimore Ravens          New York Jets        W 24-9     1              24
# 9    Sep 11, 2022      1:00  Washington Commanders   Jacksonville Jaguars       W 28-22     1              28
# 10   Sep 11, 2022      4:25     Kansas City Chiefs      Arizona Cardinals       W 44-21     1              44
# 11   Sep 11, 2022      4:25   Los Angeles Chargers      Las Vegas Raiders       W 24-19     1              24
# 12   Sep 11, 2022      4:25      Minnesota Vikings      Green Bay Packers        W 23-7     1              23
# 13   Sep 11, 2022      4:25       Tennessee Titans        New York Giants       L 20-21     1              20
# 14   Sep 11, 2022      8:20   Tampa Bay Buccaneers         Dallas Cowboys        W 19-3     1              19
# 15   Sep 12, 2022      8:20         Denver Broncos       Seattle Seahawks       L 16-17     1              16
# 16   Sep 15, 2022      8:15     Kansas City Chiefs   Los Angeles Chargers       W 27-24     2              27
# 17   Sep 18, 2022      1:00       Baltimore Ravens         Miami Dolphins       L 38-42     2              38
# 18   Sep 18, 2022      1:00       Cleveland Browns          New York Jets       L 30-31     2              30
# 19   Sep 18, 2022      1:00          Detroit Lions  Washington Commanders       W 36-27     2              36
# 20   Sep 18, 2022      1:00     Indianapolis Colts   Jacksonville Jaguars        L 0-24     2               0
# 21   Sep 18, 2022      1:00   Tampa Bay Buccaneers     New Orleans Saints       W 20-10     2              20
# 22   Sep 18, 2022      1:00        New York Giants      Carolina Panthers       W 19-16     2              19
# 23   Sep 18, 2022      1:00   New England Patriots    Pittsburgh Steelers       W 17-14     2              17
# 24   Sep 18, 2022      4:04       Los Angeles Rams        Atlanta Falcons       W 31-27     2              31
# 25   Sep 18, 2022      4:04    San Francisco 49ers       Seattle Seahawks        W 27-7     2              27
# 26   Sep 18, 2022      4:25     Cincinnati Bengals         Dallas Cowboys       L 17-20     2              17
# 27   Sep 18, 2022      4:25         Denver Broncos         Houston Texans        W 16-9     2              16
# 28   Sep 18, 2022      4:25      Las Vegas Raiders      Arizona Cardinals  L 23-29 (OT)     2              23
# 29   Sep 18, 2022      8:20      Green Bay Packers          Chicago Bears       W 27-10     2              27
# 30   Sep 19, 2022      7:15          Buffalo Bills       Tennessee Titans        W 41-7     2              41
# 31   Sep 19, 2022      8:30    Philadelphia Eagles      Minnesota Vikings        W 24-7     2              24
# 32   Sep 22, 2022      8:15       Cleveland Browns    Pittsburgh Steelers       W 29-17     3              29
# 33   Sep 25, 2022      1:00     New Orleans Saints      Carolina Panthers       L 14-22     3              14
# 34   Sep 25, 2022      1:00          Chicago Bears         Houston Texans       W 23-20     3              23
# 35   Sep 25, 2022      1:00     Kansas City Chiefs     Indianapolis Colts       L 17-20     3              17
# 36   Sep 25, 2022      1:00          Buffalo Bills         Miami Dolphins       L 19-21     3              19
# 37   Sep 25, 2022      1:00      Minnesota Vikings          Detroit Lions       W 28-24     3              28
# 38   Sep 25, 2022      1:00       Baltimore Ravens   New England Patriots       W 37-26     3              37
# 39   Sep 25, 2022      1:00     Cincinnati Bengals          New York Jets       W 27-12     3              27
# 40   Sep 25, 2022      1:00      Las Vegas Raiders       Tennessee Titans       L 22-24     3              22
# 41   Sep 25, 2022      1:00    Philadelphia Eagles  Washington Commanders        W 24-8     3              24
# 42   Sep 25, 2022      4:04   Los Angeles Chargers   Jacksonville Jaguars       L 10-38     3              10
# 43   Sep 25, 2022      4:25       Los Angeles Rams      Arizona Cardinals       W 20-12     3              20
# 44   Sep 25, 2022      4:25       Seattle Seahawks        Atlanta Falcons       L 23-27     3              23
# 45   Sep 25, 2022      4:25   Tampa Bay Buccaneers      Green Bay Packers       L 12-14     3              12
# 46   Sep 25, 2022      8:20    San Francisco 49ers         Denver Broncos       L 10-11     3              10
# 47   Sep 26, 2022      8:15        New York Giants         Dallas Cowboys       L 16-23     3              16
# 48   Sep 29, 2022      8:15     Cincinnati Bengals         Miami Dolphins       W 27-15     4              27
# 49    Oct 2, 2022      9:29      Minnesota Vikings     New Orleans Saints       W 28-25     4              28
# 50    Oct 2, 2022      1:00       Cleveland Browns        Atlanta Falcons       L 20-23     4              20
# 51    Oct 2, 2022      1:00          Buffalo Bills       Baltimore Ravens       W 23-20     4              23
# 52    Oct 2, 2022      1:00         Dallas Cowboys  Washington Commanders       W 25-10     4              25
# 53    Oct 2, 2022      1:00          Detroit Lions       Seattle Seahawks       L 45-48     4              45
# 54    Oct 2, 2022      1:00   Los Angeles Chargers         Houston Texans       W 34-24     4              34
# 55    Oct 2, 2022      1:00     Indianapolis Colts       Tennessee Titans       L 17-24     4              17
# 56    Oct 2, 2022      1:00        New York Giants          Chicago Bears       W 20-12     4              20
# 57    Oct 2, 2022      1:00    Philadelphia Eagles   Jacksonville Jaguars       W 29-21     4              29
# 58    Oct 2, 2022      1:00    Pittsburgh Steelers          New York Jets       L 20-24     4              20
# 59    Oct 2, 2022      4:04      Carolina Panthers      Arizona Cardinals       L 16-26     4              16
# 60    Oct 2, 2022      4:25      Green Bay Packers   New England Patriots  W 27-24 (OT)     4              27
# 61    Oct 2, 2022      4:25      Las Vegas Raiders         Denver Broncos       W 32-23     4              32
# 62    Oct 2, 2022      8:20   Tampa Bay Buccaneers     Kansas City Chiefs       L 31-41     4              31
# 63    Oct 3, 2022      8:15    San Francisco 49ers       Los Angeles Rams        W 24-9     4              24
# 64    Oct 6, 2022      8:15         Denver Broncos     Indianapolis Colts   L 9-12 (OT)     5               9
# 65    Oct 9, 2022      9:29      Green Bay Packers        New York Giants       L 22-27     5              22
# 66    Oct 9, 2022      1:00          Buffalo Bills    Pittsburgh Steelers        W 38-3     5              38
# 67    Oct 9, 2022      1:00   Los Angeles Chargers       Cleveland Browns       W 30-28     5              30
# 68    Oct 9, 2022      1:00   Jacksonville Jaguars         Houston Texans        L 6-13     5               6
# 69    Oct 9, 2022      1:00      Minnesota Vikings          Chicago Bears       W 29-22     5              29
# 70    Oct 9, 2022      1:00   New England Patriots          Detroit Lions        W 29-0     5              29
# 71    Oct 9, 2022      1:00     New Orleans Saints       Seattle Seahawks       W 39-32     5              39
# 72    Oct 9, 2022      1:00         Miami Dolphins          New York Jets       L 17-40     5              17
# 73    Oct 9, 2022      1:00   Tampa Bay Buccaneers        Atlanta Falcons       W 21-15     5              21
# 74    Oct 9, 2022      1:00       Tennessee Titans  Washington Commanders       W 21-17     5              21
# 75    Oct 9, 2022      4:04    San Francisco 49ers      Carolina Panthers       W 37-15     5              37
# 76    Oct 9, 2022      4:25    Philadelphia Eagles      Arizona Cardinals       W 20-17     5              20
# 77    Oct 9, 2022      4:25       Los Angeles Rams         Dallas Cowboys       L 10-22     5              10
# 78    Oct 9, 2022      8:20       Baltimore Ravens     Cincinnati Bengals       W 19-17     5              19
# 79   Oct 10, 2022      8:15     Kansas City Chiefs      Las Vegas Raiders       W 30-29     5              30
# 80   Oct 13, 2022      8:15  Washington Commanders          Chicago Bears        W 12-7     6              12
# 81   Oct 16, 2022      1:00    San Francisco 49ers        Atlanta Falcons       L 14-28     6              14
# 82   Oct 16, 2022      1:00       Cleveland Browns   New England Patriots       L 15-38     6              15
# 83   Oct 16, 2022      1:00      Green Bay Packers          New York Jets       L 10-27     6              10
# 84   Oct 16, 2022      1:00     Indianapolis Colts   Jacksonville Jaguars       W 34-27     6              34
# 85   Oct 16, 2022      1:00      Minnesota Vikings         Miami Dolphins       W 24-16     6              24
# 86   Oct 16, 2022      1:00     Cincinnati Bengals     New Orleans Saints       W 30-26     6              30
# 87   Oct 16, 2022      1:00       Baltimore Ravens        New York Giants       L 20-24     6              20
# 88   Oct 16, 2022      1:00   Tampa Bay Buccaneers    Pittsburgh Steelers       L 18-20     6              18
# 89   Oct 16, 2022      4:04       Los Angeles Rams      Carolina Panthers       W 24-10     6              24
# 90   Oct 16, 2022      4:04      Arizona Cardinals       Seattle Seahawks        L 9-19     6               9
# 91   Oct 16, 2022      4:25          Buffalo Bills     Kansas City Chiefs       W 24-20     6              24
# 92   Oct 16, 2022      8:20    Philadelphia Eagles         Dallas Cowboys       W 26-17     6              26
# 93   Oct 17, 2022      8:15   Los Angeles Chargers         Denver Broncos  W 19-16 (OT)     6              19
# 94   Oct 20, 2022      8:15      Arizona Cardinals     New Orleans Saints       W 42-34     7              42
# 95   Oct 23, 2022      1:00       Baltimore Ravens       Cleveland Browns       W 23-20     7              23
# 96   Oct 23, 2022      1:00   Tampa Bay Buccaneers      Carolina Panthers        L 3-21     7               3
# 97   Oct 23, 2022      1:00     Cincinnati Bengals        Atlanta Falcons       W 35-17     7              35
# 98   Oct 23, 2022      1:00         Dallas Cowboys          Detroit Lions        W 24-6     7              24
# 99   Oct 23, 2022      1:00   Jacksonville Jaguars        New York Giants       L 17-23     7              17
# 100  Oct 23, 2022      1:00       Tennessee Titans     Indianapolis Colts       W 19-10     7              19
# 101  Oct 23, 2022      1:00      Green Bay Packers  Washington Commanders       L 21-23     7              21
# 102  Oct 23, 2022      4:04          New York Jets         Denver Broncos        W 16-9     7              16
# 103  Oct 23, 2022      4:04      Las Vegas Raiders         Houston Texans       W 38-20     7              38
# 104  Oct 23, 2022      4:25   Los Angeles Chargers       Seattle Seahawks       L 23-37     7              23
# 105  Oct 23, 2022      4:25     Kansas City Chiefs    San Francisco 49ers       W 44-23     7              44
# 106  Oct 23, 2022      8:20         Miami Dolphins    Pittsburgh Steelers       W 16-10     7              16
# 107  Oct 24, 2022      8:15   New England Patriots          Chicago Bears       L 14-33     7              14
# 108  Oct 27, 2022      8:15   Tampa Bay Buccaneers       Baltimore Ravens       L 22-27     8              22
# 109  Oct 30, 2022      9:29   Jacksonville Jaguars         Denver Broncos       L 17-21     8              17
# 110  Oct 30, 2022      1:00        Atlanta Falcons      Carolina Panthers  W 37-34 (OT)     8              37
# 111  Oct 30, 2022      1:00         Dallas Cowboys          Chicago Bears       W 49-29     8              49
# 112  Oct 30, 2022      1:00         Miami Dolphins          Detroit Lions       W 31-27     8              31
# 113  Oct 30, 2022      1:00      Minnesota Vikings      Arizona Cardinals       W 34-26     8              34
# 114  Oct 30, 2022      1:00      Las Vegas Raiders     New Orleans Saints        L 0-24     8               0
# 115  Oct 30, 2022      1:00   New England Patriots          New York Jets       W 22-17     8              22
# 116  Oct 30, 2022      1:00    Philadelphia Eagles    Pittsburgh Steelers       W 35-13     8              35
# 117  Oct 30, 2022      4:04       Tennessee Titans         Houston Texans       W 17-10     8              17
# 118  Oct 30, 2022      4:04       Seattle Seahawks        New York Giants       W 27-13     8              27
# 119  Oct 30, 2022      4:25     Indianapolis Colts  Washington Commanders       L 16-17     8              16
# 120  Oct 30, 2022      4:25       Los Angeles Rams    San Francisco 49ers       L 14-31     8              14
# 121  Oct 30, 2022      8:20          Buffalo Bills      Green Bay Packers       W 27-17     8              27
# 122  Oct 31, 2022      8:15     Cincinnati Bengals       Cleveland Browns       L 13-32     8              13
# 0     Sep 8, 2022      8:20       Los Angeles Rams          Buffalo Bills       W 31-10     1              10
# 1    Sep 11, 2022      1:00        Atlanta Falcons     New Orleans Saints       W 27-26     1              26
# 2    Sep 11, 2022      1:00       Cleveland Browns      Carolina Panthers       L 24-26     1              26
# 3    Sep 11, 2022      1:00          Chicago Bears    San Francisco 49ers       L 10-19     1              19
# 4    Sep 11, 2022      1:00    Pittsburgh Steelers     Cincinnati Bengals  L 20-23 (OT)     1              23
# 5    Sep 11, 2022      1:00          Detroit Lions    Philadelphia Eagles       W 38-35     1              35
# 6    Sep 11, 2022      1:00         Houston Texans     Indianapolis Colts  T 20-20 (OT)     1              20
# 7    Sep 11, 2022      1:00   New England Patriots         Miami Dolphins        W 20-7     1               7
# 8    Sep 11, 2022      1:00          New York Jets       Baltimore Ravens        W 24-9     1               9
# 9    Sep 11, 2022      1:00   Jacksonville Jaguars  Washington Commanders       W 28-22     1              22
# 10   Sep 11, 2022      4:25      Arizona Cardinals     Kansas City Chiefs       W 44-21     1              21
# 11   Sep 11, 2022      4:25      Las Vegas Raiders   Los Angeles Chargers       W 24-19     1              19
# 12   Sep 11, 2022      4:25      Green Bay Packers      Minnesota Vikings        W 23-7     1               7
# 13   Sep 11, 2022      4:25        New York Giants       Tennessee Titans       L 20-21     1              21
# 14   Sep 11, 2022      8:20         Dallas Cowboys   Tampa Bay Buccaneers        W 19-3     1               3
# 15   Sep 12, 2022      8:20       Seattle Seahawks         Denver Broncos       L 16-17     1              17
# 16   Sep 15, 2022      8:15   Los Angeles Chargers     Kansas City Chiefs       W 27-24     2              24
# 17   Sep 18, 2022      1:00         Miami Dolphins       Baltimore Ravens       L 38-42     2              42
# 18   Sep 18, 2022      1:00          New York Jets       Cleveland Browns       L 30-31     2              31
# 19   Sep 18, 2022      1:00  Washington Commanders          Detroit Lions       W 36-27     2              27
# 20   Sep 18, 2022      1:00   Jacksonville Jaguars     Indianapolis Colts        L 0-24     2              24
# 21   Sep 18, 2022      1:00     New Orleans Saints   Tampa Bay Buccaneers       W 20-10     2              10
# 22   Sep 18, 2022      1:00      Carolina Panthers        New York Giants       W 19-16     2              16
# 23   Sep 18, 2022      1:00    Pittsburgh Steelers   New England Patriots       W 17-14     2              14
# 24   Sep 18, 2022      4:04        Atlanta Falcons       Los Angeles Rams       W 31-27     2              27
# 25   Sep 18, 2022      4:04       Seattle Seahawks    San Francisco 49ers        W 27-7     2               7
# 26   Sep 18, 2022      4:25         Dallas Cowboys     Cincinnati Bengals       L 17-20     2              20
# 27   Sep 18, 2022      4:25         Houston Texans         Denver Broncos        W 16-9     2               9
# 28   Sep 18, 2022      4:25      Arizona Cardinals      Las Vegas Raiders  L 23-29 (OT)     2              29
# 29   Sep 18, 2022      8:20          Chicago Bears      Green Bay Packers       W 27-10     2              10
# 30   Sep 19, 2022      7:15       Tennessee Titans          Buffalo Bills        W 41-7     2               7
# 31   Sep 19, 2022      8:30      Minnesota Vikings    Philadelphia Eagles        W 24-7     2               7
# 32   Sep 22, 2022      8:15    Pittsburgh Steelers       Cleveland Browns       W 29-17     3              17
# 33   Sep 25, 2022      1:00      Carolina Panthers     New Orleans Saints       L 14-22     3              22
# 34   Sep 25, 2022      1:00         Houston Texans          Chicago Bears       W 23-20     3              20
# 35   Sep 25, 2022      1:00     Indianapolis Colts     Kansas City Chiefs       L 17-20     3              20
# 36   Sep 25, 2022      1:00         Miami Dolphins          Buffalo Bills       L 19-21     3              21
# 37   Sep 25, 2022      1:00          Detroit Lions      Minnesota Vikings       W 28-24     3              24
# 38   Sep 25, 2022      1:00   New England Patriots       Baltimore Ravens       W 37-26     3              26
# 39   Sep 25, 2022      1:00          New York Jets     Cincinnati Bengals       W 27-12     3              12
# 40   Sep 25, 2022      1:00       Tennessee Titans      Las Vegas Raiders       L 22-24     3              24
# 41   Sep 25, 2022      1:00  Washington Commanders    Philadelphia Eagles        W 24-8     3               8
# 42   Sep 25, 2022      4:04   Jacksonville Jaguars   Los Angeles Chargers       L 10-38     3              38
# 43   Sep 25, 2022      4:25      Arizona Cardinals       Los Angeles Rams       W 20-12     3              12
# 44   Sep 25, 2022      4:25        Atlanta Falcons       Seattle Seahawks       L 23-27     3              27
# 45   Sep 25, 2022      4:25      Green Bay Packers   Tampa Bay Buccaneers       L 12-14     3              14
# 46   Sep 25, 2022      8:20         Denver Broncos    San Francisco 49ers       L 10-11     3              11
# 47   Sep 26, 2022      8:15         Dallas Cowboys        New York Giants       L 16-23     3              23
# 48   Sep 29, 2022      8:15         Miami Dolphins     Cincinnati Bengals       W 27-15     4              15
# 49    Oct 2, 2022      9:29     New Orleans Saints      Minnesota Vikings       W 28-25     4              25
# 50    Oct 2, 2022      1:00        Atlanta Falcons       Cleveland Browns       L 20-23     4              23
# 51    Oct 2, 2022      1:00       Baltimore Ravens          Buffalo Bills       W 23-20     4              20
# 52    Oct 2, 2022      1:00  Washington Commanders         Dallas Cowboys       W 25-10     4              10
# 53    Oct 2, 2022      1:00       Seattle Seahawks          Detroit Lions       L 45-48     4              48
# 54    Oct 2, 2022      1:00         Houston Texans   Los Angeles Chargers       W 34-24     4              24
# 55    Oct 2, 2022      1:00       Tennessee Titans     Indianapolis Colts       L 17-24     4              24
# 56    Oct 2, 2022      1:00          Chicago Bears        New York Giants       W 20-12     4              12
# 57    Oct 2, 2022      1:00   Jacksonville Jaguars    Philadelphia Eagles       W 29-21     4              21
# 58    Oct 2, 2022      1:00          New York Jets    Pittsburgh Steelers       L 20-24     4              24
# 59    Oct 2, 2022      4:04      Arizona Cardinals      Carolina Panthers       L 16-26     4              26
# 60    Oct 2, 2022      4:25   New England Patriots      Green Bay Packers  W 27-24 (OT)     4              24
# 61    Oct 2, 2022      4:25         Denver Broncos      Las Vegas Raiders       W 32-23     4              23
# 62    Oct 2, 2022      8:20     Kansas City Chiefs   Tampa Bay Buccaneers       L 31-41     4              41
# 63    Oct 3, 2022      8:15       Los Angeles Rams    San Francisco 49ers        W 24-9     4               9
# 64    Oct 6, 2022      8:15     Indianapolis Colts         Denver Broncos   L 9-12 (OT)     5              12
# 65    Oct 9, 2022      9:29        New York Giants      Green Bay Packers       L 22-27     5              27
# 66    Oct 9, 2022      1:00    Pittsburgh Steelers          Buffalo Bills        W 38-3     5               3
# 67    Oct 9, 2022      1:00       Cleveland Browns   Los Angeles Chargers       W 30-28     5              28
# 68    Oct 9, 2022      1:00         Houston Texans   Jacksonville Jaguars        L 6-13     5              13
# 69    Oct 9, 2022      1:00          Chicago Bears      Minnesota Vikings       W 29-22     5              22
# 70    Oct 9, 2022      1:00          Detroit Lions   New England Patriots        W 29-0     5               0
# 71    Oct 9, 2022      1:00       Seattle Seahawks     New Orleans Saints       W 39-32     5              32
# 72    Oct 9, 2022      1:00          New York Jets         Miami Dolphins       L 17-40     5              40
# 73    Oct 9, 2022      1:00        Atlanta Falcons   Tampa Bay Buccaneers       W 21-15     5              15
# 74    Oct 9, 2022      1:00  Washington Commanders       Tennessee Titans       W 21-17     5              17
# 75    Oct 9, 2022      4:04      Carolina Panthers    San Francisco 49ers       W 37-15     5              15
# 76    Oct 9, 2022      4:25      Arizona Cardinals    Philadelphia Eagles       W 20-17     5              17
# 77    Oct 9, 2022      4:25         Dallas Cowboys       Los Angeles Rams       L 10-22     5              22
# 78    Oct 9, 2022      8:20     Cincinnati Bengals       Baltimore Ravens       W 19-17     5              17
# 79   Oct 10, 2022      8:15      Las Vegas Raiders     Kansas City Chiefs       W 30-29     5              29
# 80   Oct 13, 2022      8:15          Chicago Bears  Washington Commanders        W 12-7     6               7
# 81   Oct 16, 2022      1:00        Atlanta Falcons    San Francisco 49ers       L 14-28     6              28
# 82   Oct 16, 2022      1:00   New England Patriots       Cleveland Browns       L 15-38     6              38
# 83   Oct 16, 2022      1:00          New York Jets      Green Bay Packers       L 10-27     6              27
# 84   Oct 16, 2022      1:00   Jacksonville Jaguars     Indianapolis Colts       W 34-27     6              27
# 85   Oct 16, 2022      1:00         Miami Dolphins      Minnesota Vikings       W 24-16     6              16
# 86   Oct 16, 2022      1:00     New Orleans Saints     Cincinnati Bengals       W 30-26     6              26
# 87   Oct 16, 2022      1:00        New York Giants       Baltimore Ravens       L 20-24     6              24
# 88   Oct 16, 2022      1:00    Pittsburgh Steelers   Tampa Bay Buccaneers       L 18-20     6              20
# 89   Oct 16, 2022      4:04      Carolina Panthers       Los Angeles Rams       W 24-10     6              10
# 90   Oct 16, 2022      4:04       Seattle Seahawks      Arizona Cardinals        L 9-19     6              19
# 91   Oct 16, 2022      4:25     Kansas City Chiefs          Buffalo Bills       W 24-20     6              20
# 92   Oct 16, 2022      8:20         Dallas Cowboys    Philadelphia Eagles       W 26-17     6              17
# 93   Oct 17, 2022      8:15         Denver Broncos   Los Angeles Chargers  W 19-16 (OT)     6              16
# 94   Oct 20, 2022      8:15     New Orleans Saints      Arizona Cardinals       W 42-34     7              34
# 95   Oct 23, 2022      1:00       Cleveland Browns       Baltimore Ravens       W 23-20     7              20
# 96   Oct 23, 2022      1:00      Carolina Panthers   Tampa Bay Buccaneers        L 3-21     7              21
# 97   Oct 23, 2022      1:00        Atlanta Falcons     Cincinnati Bengals       W 35-17     7              17
# 98   Oct 23, 2022      1:00          Detroit Lions         Dallas Cowboys        W 24-6     7               6
# 99   Oct 23, 2022      1:00        New York Giants   Jacksonville Jaguars       L 17-23     7              23
# 100  Oct 23, 2022      1:00     Indianapolis Colts       Tennessee Titans       W 19-10     7              10
# 101  Oct 23, 2022      1:00  Washington Commanders      Green Bay Packers       L 21-23     7              23
# 102  Oct 23, 2022      4:04         Denver Broncos          New York Jets        W 16-9     7               9
# 103  Oct 23, 2022      4:04         Houston Texans      Las Vegas Raiders       W 38-20     7              20
# 104  Oct 23, 2022      4:25       Seattle Seahawks   Los Angeles Chargers       L 23-37     7              37
# 105  Oct 23, 2022      4:25    San Francisco 49ers     Kansas City Chiefs       W 44-23     7              23
# 106  Oct 23, 2022      8:20    Pittsburgh Steelers         Miami Dolphins       W 16-10     7              10
# 107  Oct 24, 2022      8:15          Chicago Bears   New England Patriots       L 14-33     7              33
# 108  Oct 27, 2022      8:15       Baltimore Ravens   Tampa Bay Buccaneers       L 22-27     8              27
# 109  Oct 30, 2022      9:29         Denver Broncos   Jacksonville Jaguars       L 17-21     8              21
# 110  Oct 30, 2022      1:00      Carolina Panthers        Atlanta Falcons  W 37-34 (OT)     8              34
# 111  Oct 30, 2022      1:00          Chicago Bears         Dallas Cowboys       W 49-29     8              29
# 112  Oct 30, 2022      1:00          Detroit Lions         Miami Dolphins       W 31-27     8              27
# 113  Oct 30, 2022      1:00      Arizona Cardinals      Minnesota Vikings       W 34-26     8              26
# 114  Oct 30, 2022      1:00     New Orleans Saints      Las Vegas Raiders        L 0-24     8              24
# 115  Oct 30, 2022      1:00          New York Jets   New England Patriots       W 22-17     8              17
# 116  Oct 30, 2022      1:00    Pittsburgh Steelers    Philadelphia Eagles       W 35-13     8              13
# 117  Oct 30, 2022      4:04         Houston Texans       Tennessee Titans       W 17-10     8              10
# 118  Oct 30, 2022      4:04        New York Giants       Seattle Seahawks       W 27-13     8              13
# 119  Oct 30, 2022      4:25  Washington Commanders     Indianapolis Colts       L 16-17     8              17
# 120  Oct 30, 2022      4:25    San Francisco 49ers       Los Angeles Rams       L 14-31     8              31
# 121  Oct 30, 2022      8:20      Green Bay Packers          Buffalo Bills       W 27-17     8              17
# 122  Oct 31, 2022      8:15       Cleveland Browns     Cincinnati Bengals       L 13-32     8              32
